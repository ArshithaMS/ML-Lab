# %%
import random
import csv
def g_0(n):
    return ("?",)*n

def s_0(n):
    return ('0',)*n

def more_general(h1,h2):
    more_general_parts=[]
    for x,y in zip(h1,h2):
        mg=x=="?" or (x != "0" and (x==y or y=="0"))
        more_general_parts.append(mg)
    return all(more_general_parts)

l1=[1,2,3]
l2=[3,4,5]

list(zip(l1,l2))
def fulfills(example,hypothesis):
    return more_general(hypothesis,example)

def min_generelizations(h,x):
    h_new=list(h)
    for i in range(len(h)):
        if not fulfills(x[i:i+1],h[i:i+1]):
            h_new[i]='?' if h[i] !='0' else x[i]
    return [tuple(h_new)]
min_generelizations(h=('0','0','sunny'),
                   x=('rainy','windy','cloudy'))

def min_specializations(h,domains,x):
    results=[]
    for i in range(len(h)):
        if h[i]=='?':
            for val in domains[i]:
                if x[i]!=val:
                    h_new=h[:1]+(val,)+h[i+1:]
                    results.append(h_new)
                    
                elif h[i] !="0":
                    h_new=h[:i]+('0',)+h[i+1:] 
                    results.append(h_new)
            return results
min_specializations(h=('?','x',),domains=[['a','b','c'],['x','y']],x=('b','x'))
with open('tennis1.csv') as csvFile:
    examples=[tuple(line) for line in csv.reader(csvFile)]
examples
def get_domains(examples):
    d=[set() for i in examples[0]]
    for x in examples:
        for i,x1 in enumerate(x):
            d[i].add(x1)
        return [list(sorted(x)) for x in d]
get_domains(examples)

def candidate_elimination(examples):
    domains=get_domains(examples)[:-1]
    
    G=set([g_0(len(domains))])
    S=set([s_0(len(domains))])
    i=0
    print("\n G[{0}]:".format(i),G)
    print("\n S[{0}]:".format(i),S)
    for xcx in examples:
        i=i+1
        x,cx=xcx[:-1],xcx[-1]
        if cx=='y':
            G={g for g in G if fulfills(x,g)}
            S=generelize_S(x,G,S)
        else:
            S={S for s in S if not fulfills(x,s)}
            G=specialize_G(x,domains,G,S)
        print("\n G[{0}]:".format(i),G)
        print("\n S[{0}]:".format(i),S)
    return

def generelize_S(x,G,S):
    S_prev=list(S)
    for s in S_prev:
        if s not in S:
            continue
        if not fulfills(x,s):
            S.remove(s)
            Splus=min_generelizations(s,x)
            S.update([h for h in Splus if any([more_general(g,h) for g in G])])
            S.difference_update([h for h in S if any([more_general(h,h1) for h1 in S if h!=h1])])
        return S
def specialize_G(x,domain,G,S):
    G_prev=list(G)
    for g in G_prev:
        if g not in G:
            continue
        if fulfills(x,g):
            G.remove(g)
            Gminus=min_specializations(g,domains,x)
            G.update([h for h in Gminus if any([more_general(h,s) for s in S])])
            G.difference_update([h for h in G if any([more_general(g1,h) for g1 in G if h!=g1])])
    return G
candidate_elimination(examples)
# Out:
#  G[0]: {('?', '?', '?', '?', '?', '?')}
#
#  S[0]: {('0', '0', '0', '0', '0', '0')}
#
#  G[1]: {('?', '?', '?', '?', '?', '?')}
#
#  S[1]: {('sunny', 'warm', 'normal', 'strong', 'warm', 'same')}
#
#  G[2]: {('?', '?', '?', '?', '?', '?')}
#
#  S[2]: {('sunny', 'warm', '?', 'strong', 'warm', 'same')}
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-d3f27814f010> in <module>()
#      98             G.difference_update([h for h in G if any([more_general(g1,h) for g1 in G if h!=g1])])
#      99     return G
# --> 100 candidate_elimination(examples)
#
# <ipython-input-17-d3f27814f010> in candidate_elimination(examples)
#      70             S=generelize_S(x,G,S)
#      71         else:
# ---> 72             S={S for s in S if not fulfills(x,s)}
#      73             G=specialize_G(x,domains,G,S)
#      74         print("\n G[{0}]:".format(i),G)
#
# <ipython-input-17-d3f27814f010> in <setcomp>(.0)
#      70             S=generelize_S(x,G,S)
#      71         else:
# ---> 72             S={S for s in S if not fulfills(x,s)}
#      73             G=specialize_G(x,domains,G,S)
#      74         print("\n G[{0}]:".format(i),G)
#
# TypeError: unhashable type: 'set'
